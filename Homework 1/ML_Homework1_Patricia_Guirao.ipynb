# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import sklearn
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('housingUnits.csv')

# %%
df
# Out:
#        housing_median_age  total_rooms  total_bedrooms  population  \
# 0                      41          880             223         322
# 1                      21         7099            1338        2401
# 2                      52         1467             328         496
# 3                      52         1274             293         558
# 4                      52         1627             357         565
# ...                   ...          ...             ...         ...
# 20635                  25         1665             364         845
# 20636                  18          697             190         356
# 20637                  17         2254             469        1007
# 20638                  18         1860             399         741
# 20639                  16         2785             565        1387
#
#        households  median_income  ocean_proximity  median_house_value
# 0             126       208.1300                1              452600
# ...

# %% [markdown]
# # Question 1

# %%
plt.plot(df['total_rooms'],  df['population'],'o',markersize=.75)
plt.gcf().set_size_inches(8, 5)
plt.xlabel('Total Number of Rooms') 
plt.ylabel('Population')
# Out:
# Text(0, 0.5, 'Population')

# %%
df['total_rooms'].corr(df['population'])
# Out:
# 0.8571259728659778

# %%
plt.plot(df['total_rooms'],  df['households'],'o',markersize=.75) 
plt.gcf().set_size_inches(8, 5)
plt.xlabel('Total Number of Rooms') 
plt.ylabel('Number of Households')
# Out:
# Text(0, 0.5, 'Number of Households')

# %%
df['total_rooms'].corr(df['households'])
# Out:
# 0.9184844926543082

# %%
plt.plot(df['total_bedrooms'],  df['population'],'o',markersize=.75) 
plt.gcf().set_size_inches(8, 5)
plt.xlabel('Total Number of Bedrooms') 
plt.ylabel('Population')
# Out:
# Text(0, 0.5, 'Population')

# %%
df['total_bedrooms'].corr(df['population'])
# Out:
# 0.857117684317181

# %%
plt.plot(df['total_bedrooms'],  df['households'],'o',markersize=.75) 
plt.gcf().set_size_inches(8, 5)
plt.xlabel('Total Number of Bedrooms') 
plt.ylabel('Number of Households')
# Out:
# Text(0, 0.5, 'Number of Households')

# %%
df['total_bedrooms'].corr(df['households'])
# Out:
# 0.9184811413083975

# %%
df['population'].corr(df['median_house_value'])
# Out:
# -0.02464967888889488

# %%
df['households'].corr(df['median_house_value'])
# Out:
# 0.06584265057005646

# %% [markdown]
# # Question 2

# %%
x_p2_p4 = (df['total_rooms']/df['population']).to_numpy().reshape(-1, 1)
y = df['median_house_value'].to_numpy().reshape(-1, 1)
model1 = LinearRegression().fit(x_p2_p4, y)
rSqr = model1.score(x_p2_p4, y)
print(rSqr)

yHat = model1.predict(x_p2_p4)
plt.plot(yHat,y,'o',markersize=.75)
plt.xlabel('Prediction from Model (Total Rooms/Population)') 
plt.ylabel('Median House Value')  
plt.title('R^2 = {:.3f}'.format(rSqr))
# Out:
# 0.043882695338919864
# Text(0.5, 1.0, 'R^2 = 0.044')

# %%
x_p2_p5 = (df['total_rooms']/df['households']).to_numpy().reshape(-1, 1)
y = df['median_house_value'].to_numpy().reshape(-1, 1)
model1 = LinearRegression().fit(x_p2_p5, y)
rSqr = model1.score(x_p2_p5, y)
print(rSqr)

yHat = model1.predict(x_p2_p5)
plt.plot(yHat,y,'o',markersize=.75) 
plt.xlabel('Prediction from Model (Total Rooms/Households)') 
plt.ylabel('Median House Value')  
plt.title('R^2 = {:.3f}'.format(rSqr))
# Out:
# 0.023088282755354128
# Text(0.5, 1.0, 'R^2 = 0.023')

# %%
x_p3_p4 = (df['total_bedrooms']/df['population']).to_numpy().reshape(-1, 1)
y = df['median_house_value'].to_numpy().reshape(-1, 1)
model1 = LinearRegression().fit(x_p3_p4, y)
rSqr = model1.score(x_p3_p4, y)
print(rSqr)

yHat = model1.predict(x_p3_p4)
plt.plot(yHat,y,'o',markersize=.75) 
plt.xlabel('Prediction from Model (Total Bedrooms/Population)') 
plt.ylabel('Median House Value')  
plt.title('R^2 = {:.3f}'.format(rSqr))
# Out:
# 0.012790501296178869
# Text(0.5, 1.0, 'R^2 = 0.013')

# %%
x_p3_p5 = (df['total_bedrooms']/df['households']).to_numpy().reshape(-1, 1)
y = df['median_house_value'].to_numpy().reshape(-1, 1)
model1 = LinearRegression().fit(x_p3_p5, y)
rSqr = model1.score(x_p3_p5, y)
print(rSqr)

yHat = model1.predict(x_p3_p5)
plt.plot(yHat,y,'o',markersize=.75) 
plt.xlabel('Prediction from Model (Total Bedrooms/Households)') 
plt.ylabel('Median House Value')  
plt.title('R^2 = {:.3f}'.format(rSqr))
# Out:
# 0.003394278159693398
# Text(0.5, 1.0, 'R^2 = 0.003')

# %%
df['total_rooms'] = df['total_rooms']/df['population']

# %%
df['total_bedrooms'] = df['total_bedrooms']/df['population']

# %%
df = df.rename(columns = {'total_rooms':'avg_rooms', 'total_bedrooms':'avg_bedrooms'})

# %%
df
# Out:
#        housing_median_age  avg_rooms  avg_bedrooms  population  households  \
# 0                      41   2.732919      0.692547         322         126
# 1                      21   2.956685      0.557268        2401        1138
# 2                      52   2.957661      0.661290         496         177
# 3                      52   2.283154      0.525090         558         219
# 4                      52   2.879646      0.631858         565         259
# ...                   ...        ...           ...         ...         ...
# 20635                  25   1.970414      0.430769         845         330
# 20636                  18   1.957865      0.533708         356         114
# 20637                  17   2.238332      0.465740        1007         433
# 20638                  18   2.510121      0.538462         741         349
# 20639                  16   2.007931      0.407354        1387         530
#
#        median_income  ocean_proximity  median_house_value
# ...

# %% [markdown]
# # Question 3

# %%
x1 = df['housing_median_age'].to_numpy().reshape(-1, 1)
y = df['median_house_value'].to_numpy().reshape(-1, 1)
model1 = LinearRegression().fit(x1, y)
rSqr = model1.score(x1, y)
print(rSqr)

yHat = model1.predict(x1)
plt.plot(yHat,y,'o',markersize=.75) 
plt.xlabel('Prediction from Model (Housing Median Age)') 
plt.ylabel('Median House Value')  
plt.title('R^2 = {:.3f}'.format(rSqr))
# Out:
# 0.011156305266710853
# Text(0.5, 1.0, 'R^2 = 0.011')

# %%
x2 = df['avg_rooms'].to_numpy().reshape(-1, 1)
y = df['median_house_value'].to_numpy().reshape(-1, 1)
model2 = LinearRegression().fit(x2, y)
rSqr = model2.score(x2, y)
print(rSqr)

yHat = model1.predict(x2)
plt.plot(yHat,y,'o',markersize=.75) 
plt.xlabel('Prediction from Model (Average Rooms)') 
plt.ylabel('Median House Value')  
plt.title('R^2 = {:.3f}'.format(rSqr))
# Out:
# 0.043882695338919864
# Text(0.5, 1.0, 'R^2 = 0.044')

# %%
x3 = df['avg_bedrooms'].to_numpy().reshape(-1, 1)
y = df['median_house_value'].to_numpy().reshape(-1, 1)
model3 = LinearRegression().fit(x3, y)
rSqr = model3.score(x3, y)
print(rSqr)

yHat = model3.predict(x3)
plt.plot(yHat,y,'o',markersize=.75) 
plt.xlabel('Prediction from Model (Average Bedrooms)') 
plt.ylabel('Median House Value')  
plt.title('R^2 = {:.3f}'.format(rSqr))
# Out:
# 0.012790501296178869
# Text(0.5, 1.0, 'R^2 = 0.013')

# %%
x4 = df['population'].to_numpy().reshape(-1, 1)
y = df['median_house_value'].to_numpy().reshape(-1, 1)
model4 = LinearRegression().fit(x4, y)
rSqr = model4.score(x4, y)
print(rSqr)

yHat = model4.predict(x4)
plt.plot(yHat,y,'o',markersize=.75) 
plt.xlabel('Prediction from Model (Population)') 
plt.ylabel('Median House Value')  
plt.title('R^2 = {:.3f}'.format(rSqr))
# Out:
# 0.0006076066693256887
# Text(0.5, 1.0, 'R^2 = 0.001')

# %%
x5 = df['households'].to_numpy().reshape(-1, 1)
y = df['median_house_value'].to_numpy().reshape(-1, 1)
model5 = LinearRegression().fit(x5, y)
rSqr = model5.score(x5, y)
print(rSqr)

yHat = model5.predict(x5)
plt.plot(yHat,y,'o',markersize=.75) 
plt.xlabel('Prediction from Model (Households)') 
plt.ylabel('Median House Value')  
plt.title('R^2 = {:.3f}'.format(rSqr))
# Out:
# 0.0043352546340906795
# Text(0.5, 1.0, 'R^2 = 0.004')

# %%
x6 = df['median_income'].to_numpy().reshape(-1, 1)
y = df['median_house_value'].to_numpy().reshape(-1, 1)
model6 = LinearRegression().fit(x6, y)
rSqr = model6.score(x6, y)
print(rSqr)

yHat = model6.predict(x6)
plt.plot(yHat,y,'o',markersize=.75) 
plt.xlabel('Prediction from Model (Median Income)') 
plt.ylabel('Median House Value')  
plt.title('R^2 = {:.3f}'.format(rSqr))
# Out:
# 0.47344749180719903
# Text(0.5, 1.0, 'R^2 = 0.473')

# %%
x7 = df['ocean_proximity'].to_numpy().reshape(-1, 1)
y = df['median_house_value'].to_numpy().reshape(-1, 1)
model7 = LinearRegression().fit(x7, y)
rSqr = model7.score(x7, y)
print(rSqr)

yHat = model7.predict(x7)
plt.plot(yHat,y,'o',markersize=.75) 
plt.xlabel('Prediction from Model (Ocean Proximity)') 
plt.ylabel('Median House Value')  
plt.title('R^2 = {:.3f}'.format(rSqr))
# Out:
# 0.15780848616855137
# Text(0.5, 1.0, 'R^2 = 0.158')

# %% [markdown]
# # Question 4

# %%
x = df.iloc[:,:7].to_numpy()
y = df['median_house_value'].to_numpy()
model = LinearRegression().fit(x, y)
rSqr = model.score(x, y)
print(rSqr)

yHat = model.predict(x)
plt.plot(yHat,y,'o',markersize=.75) 
plt.xlabel('Prediction from Model') 
plt.ylabel('Median House Value')  
plt.title('R^2 = {:.3f}'.format(rSqr))
# Out:
# 0.6006645246293567
# Text(0.5, 1.0, 'R^2 = 0.601')

# %% [markdown]
# # Question 5

# %%
plt.plot(df['avg_rooms'],  df['avg_bedrooms'],'o',markersize=.75) 
plt.gcf().set_size_inches(8, 5)
plt.xlabel('Average Number of Rooms') 
plt.ylabel('Average Number of Bedrooms')
# Out:
# Text(0, 0.5, 'Average Number of Bedrooms')

# %%
df['avg_rooms'].corr(df['avg_bedrooms'])
# Out:
# 0.6414637002481952

# %%
plt.plot(df['population'],  df['households'],'o',markersize=.75) 
plt.gcf().set_size_inches(8, 5)
plt.xlabel('Population') 
plt.ylabel('Households')
# Out:
# Text(0, 0.5, 'Households')

# %%
df['population'].corr(df['households'])
# Out:
# 0.9072222660959617

# %% [markdown]
# # Extra Credit 1

# %%
fig, axs = plt.subplots(1, 1, sharey=True, tight_layout=True)
axs.hist(df['housing_median_age'], bins=None)
# Out:
# (array([ 719., 1104., 2235., 2681., 2510., 2354., 3555., 1900., 1616.,
#         1966.]),
#  array([ 1. ,  6.1, 11.2, 16.3, 21.4, 26.5, 31.6, 36.7, 41.8, 46.9, 52. ]),
#  <BarContainer object of 10 artists>)

# %%
fig, axs = plt.subplots(1, 1, sharey=True, tight_layout=True)
axs.hist(df['avg_rooms'], bins=None)
# Out:
# (array([2.0509e+04, 9.1000e+01, 2.4000e+01, 6.0000e+00, 4.0000e+00,
#         1.0000e+00, 2.0000e+00, 1.0000e+00, 0.0000e+00, 2.0000e+00]),
#  array([2.54691689e-03, 5.52451445e+00, 1.10464820e+01, 1.65684495e+01,
#         2.20904170e+01, 2.76123846e+01, 3.31343521e+01, 3.86563196e+01,
#         4.41782872e+01, 4.97002547e+01, 5.52222222e+01]),
#  <BarContainer object of 10 artists>)

# %%
fig, axs = plt.subplots(1, 1, sharey=True, tight_layout=True)
axs.hist(df['avg_bedrooms'], bins=None)
# Out:
# (array([2.0536e+04, 7.4000e+01, 1.6000e+01, 8.0000e+00, 2.0000e+00,
#         3.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00]),
#  array([9.11528150e-03, 2.27487042e+00, 4.54062556e+00, 6.80638070e+00,
#         9.07213584e+00, 1.13378910e+01, 1.36036461e+01, 1.58694013e+01,
#         1.81351564e+01, 2.04009115e+01, 2.26666667e+01]),
#  <BarContainer object of 10 artists>)

# %%
fig, axs = plt.subplots(1, 1, sharey=True, tight_layout=True)
axs.hist(df['population'], bins=None)
# Out:
# (array([1.9816e+04, 7.1100e+02, 9.5000e+01, 1.2000e+01, 4.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 1.0000e+00]),
#  array([3.00000e+00, 3.57090e+03, 7.13880e+03, 1.07067e+04, 1.42746e+04,
#         1.78425e+04, 2.14104e+04, 2.49783e+04, 2.85462e+04, 3.21141e+04,
#         3.56820e+04]),
#  <BarContainer object of 10 artists>)

# %%
fig, axs = plt.subplots(1, 1, sharey=True, tight_layout=True)
axs.hist(df['households'], bins=None)
# Out:
# (array([1.5581e+04, 4.1440e+03, 6.5000e+02, 1.5900e+02, 5.9000e+01,
#         2.3000e+01, 1.3000e+01, 6.0000e+00, 4.0000e+00, 1.0000e+00]),
#  array([1.0000e+00, 6.0910e+02, 1.2172e+03, 1.8253e+03, 2.4334e+03,
#         3.0415e+03, 3.6496e+03, 4.2577e+03, 4.8658e+03, 5.4739e+03,
#         6.0820e+03]),
#  <BarContainer object of 10 artists>)

# %%
fig, axs = plt.subplots(1, 1, sharey=True, tight_layout=True)
axs.hist(df['median_income'], bins=None)
# Out:
# (array([2247., 7436., 6098., 2990., 1060.,  428.,  178.,   93.,   47.,
#           63.]),
#  array([ 12.4975,  48.748 ,  84.9985, 121.249 , 157.4995, 193.75  ,
#         230.0005, 266.251 , 302.5015, 338.752 , 375.0025]),
#  <BarContainer object of 10 artists>)

# %%
fig, axs = plt.subplots(1, 1, sharey=True, tight_layout=True)
axs.hist(df['ocean_proximity'], bins=None)
# Out:
# (array([5.000e+00, 0.000e+00, 2.290e+03, 0.000e+00, 0.000e+00, 2.658e+03,
#         0.000e+00, 9.136e+03, 0.000e+00, 6.551e+03]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
fig, axs = plt.subplots(1, 1, sharey=True, tight_layout=True)
axs.hist(df['median_house_value'], bins=None)
# Out:
# (array([ 877., 3612., 4099., 3771., 2799., 1769., 1239.,  752.,  479.,
#         1243.]),
#  array([ 14999. ,  63499.2, 111999.4, 160499.6, 208999.8, 257500. ,
#         306000.2, 354500.4, 403000.6, 451500.8, 500001. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Extra Credit 2

# %%
fig, axs = plt.subplots(1, 1, sharey=True, tight_layout=True)
axs.hist(df['median_house_value'], bins=50)
# Out:
# (array([   9.,   14.,   61.,  255.,  538.,  676.,  546.,  803.,  881.,
#          706.,  812.,  715.,  836.,  815.,  921.,  960.,  786.,  817.,
#          703.,  505.,  620.,  661.,  578.,  508.,  437.,  434.,  463.,
#          331.,  320.,  216.,  224.,  232.,  245.,  252.,  286.,  193.,
#          160.,  149.,  117.,  133.,  104.,   99.,   80.,   90.,  106.,
#           66.,   49.,   51.,   47., 1030.]),
#  array([ 14999.  ,  24699.04,  34399.08,  44099.12,  53799.16,  63499.2 ,
#          73199.24,  82899.28,  92599.32, 102299.36, 111999.4 , 121699.44,
#         131399.48, 141099.52, 150799.56, 160499.6 , 170199.64, 179899.68,
#         189599.72, 199299.76, 208999.8 , 218699.84, 228399.88, 238099.92,
#         247799.96, 257500.  , 267200.04, 276900.08, 286600.12, 296300.16,
#         306000.2 , 315700.24, 325400.28, 335100.32, 344800.36, 354500.4 ,
#         364200.44, 373900.48, 383600.52, 393300.56, 403000.6 , 412700.64,
# ...
